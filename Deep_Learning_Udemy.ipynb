# %% [markdown]
# # Deep Learning

# %%
import numpy as np
import torch

# %% [markdown]
# ## Using Numpy

# %%
# create a vector in numpy
nv1 = np.array([1, 2, 3, 4])
nv2 = np.array([0, 1, 0, -1])

# dot product via function
print(np.dot(nv1, nv2))

# dot product via computation
print(np.sum(nv1*nv2))
# Out:
# -2
# -2

# %% [markdown]
# ## Using Pytorch

# %%
# create a vector in pytorch
tv1 = torch.tensor([1, 2, 3, 4])
tv2 = torch.tensor([0, 1, 0, -1])

# dot product via function
print(torch.dot(tv1, tv2))

# dot product via computation
print(torch.sum(tv1*tv2))
# Out:
# tensor(-2)
# tensor(-2)

# %% [markdown]
# # Matrix Multiplication

# %% [markdown]
# ## Using Numpy

# %%
# Create some random matrices

A = np.random.randn(3, 4)
B = np.random.randn(4, 5)
C = np.random.randn(3, 7)

print(f'AxB is : {A@B}\n')
print(f'A.TXC is : {A.T@C}\n')
# Out:
# AxB is : [[-0.4681895   0.90652481 -1.29432183  1.73421649  0.08869103]
#  [-0.82623908 -2.24996454 -0.50023506 -0.49672722  0.55688505]
#  [-3.21347859 -4.17277561 -0.55830733  0.61465306  4.43052886]]
#
# A.TXC is : [[ 1.21574851e+00 -2.89435135e-03 -1.98752711e+00 -3.76052295e-01
#    7.17194480e-01 -1.55884770e-01 -7.35830674e-01]
#  [-7.30263126e-02 -5.21935484e-01  3.47243564e+00  2.19712671e+00
#   -2.36137980e+00  7.94268432e-01  1.64577511e+00]
#  [ 5.75766231e-01 -3.72161459e-01 -1.14051148e+00 -1.20609743e+00
#    1.43666810e+00  1.05828603e-01 -2.21627298e+00]
#  [-1.30151676e+00  1.27851222e-01  3.64779194e-01 -1.07573548e+00
#    8.08650132e-01 -1.61461989e-01 -7.15012947e-01]]

# %% [markdown]
# ## Using Pytorch

# %%
# create some random matrices
A = torch.randn(3, 4)
B = torch.randn(4, 5)
C1 = np.random.randn(4, 7)
C2 = torch.tensor(C1, dtype=torch.float)

print(f'AxB is {A@B}')
print(f'AxC2 is {A@C2}')
print(f'C2.TxB is {C2.T@B}')
# Out:
# AxB is tensor([[ 1.7083,  0.9048, -0.5192,  0.9695, -2.9353],
#         [-1.1689,  0.3511,  0.9781, -0.8432,  3.1744],
#         [-1.9063, -1.4473,  0.1457,  0.9708,  1.7326]])
# AxC2 is tensor([[-2.3674,  0.8763,  0.5677, -3.8036, -1.9511,  2.0968, -2.1160],
#         [ 1.9130, -0.8828, -1.9121,  0.8336,  2.3950, -0.8075,  1.8467],
#         [ 0.7498, -1.1923, -0.4610,  3.0376,  0.2683, -2.2126,  1.0816]])
# C2.TxB is tensor([[ 1.1655, -1.7936,  0.2572, -0.5559,  1.2896],
#         [ 1.1756,  0.4888, -0.2120, -1.4939, -0.8910],
#         [ 1.6619, -1.9194, -0.6979, -0.0678, -1.5290],
#         [-1.1129, -2.1710, -0.3967, -0.6710,  0.8513],
#         [ 0.9984, -0.7320,  0.5376, -0.7877,  1.5995],
#         [ 1.3198,  1.6203,  0.0583, -1.3351, -0.9096],
#         [-0.1262, -0.7029,  0.3179, -0.3411,  1.3798]])

# %% [markdown]
# # Softmax

# %% [markdown]
# ## Softmax Implementation and Visualization

# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
torch.set_printoptions(precision=2)

# %%
# "manually in numpy"
z = np.arange(1, 4, 1)
num = np.exp(z)
den = np.sum(num)
sigma = num/den
print('Softmax values are ', sigma)
# Out:
# Softmax values are  [0.09003057 0.24472847 0.66524096]

# %%
# with some random integers

z1 = np.random.randint(low=-20, high=20, size=30)
print(z1)

num = np.exp(z1)
den = np.sum(num)
sigma = num / den

plt.plot(z1, sigma, 'ko')
plt.xlabel('Original number')
plt.ylabel('Softmaxified $\sigma$')
# if you uncomment the code below the function will be linear
#plt.yscale('log')
plt.title('$\sum\sigma$ = %g' %np.sum(sigma))
plt.show()
# Out:
# [  6 -15  -4  -6  13 -13   7   7  -2   8 -20 -16 -19  -6 -13  14  12 -12
#    9   5   5   3   6  -8   6 -16 -19   0  -4  -4]

# %% [markdown]
# ## Softmax using pytorch

# %%
softfun = nn.Softmax(dim=0)

sigmaT = softfun(torch.Tensor(z))

print(sigmaT)
# Out:
# tensor([0.09, 0.24, 0.67])

# %% [markdown]
# # Entropy and Cross Entropy

# %% [markdown]
# ## Using Pytorch

# %%
import torch
import torch.nn.functional as F

# %%
p = [1, 0]
q = [.25, .75]

# %%
p_tensor, q_tensor = [torch.Tensor(i) for i in [p, q]]

# %%
F.binary_cross_entropy(q_tensor, p_tensor)
# Out:
# tensor(1.39)

# %% [markdown]
# # Min/max and argmin/argmax

# %%
# import libraries

import numpy as np
import torch
import torch.nn as nn

# %% [markdown]
# ## Using numpy

# %%
v = np.array([1, 40, 2, -3])
minval = np.min(v)
maxval = np.max(v)

print('Min, max: %g, %g' %(minval, maxval))
minidx = np.argmin(v)
maxidx = np.argmax(v)
print('Min, max indices: %g, %g' %(minidx, maxidx))

print('Min , max values are',v[minidx], 'and', v[maxidx], 'respectively.')
# Out:
# Min, max: -3, 40
# Min, max indices: 3, 1
# Min , max values are -3 and 40 respectively.

# %%
# For matrices

M = np.array([[0, 1, 10], [20, 8, 5]])
print(M, ' ')
# Out:
# [[ 0  1 10]
#  [20  8  5]]

# %%
# minimas for matrices

minvals1 = np.min(M) # minimum for the whole matrix
minvals2 = np.min(M, axis=0) # minimum of each column (across rows)
minvals3 = np.min(M, axis=1) # minimum of each row (across columns)

# %%
print(minvals1)
print(minvals2)
print(minvals3)
# Out:
# 0
# [0 1 5]
# [0 5]

# %%
# minimum indices for corresponding matrix

minidx1 = np.argmin(M) # minimum for entire matrix
minidx2 = np.argmin(M, axis=0) # minimum for each column (across rows)
minidx3 = np.argmin(M, axis=1) # minimum for each row (across columns)

# print indices

print(M, ' ')
print(minidx1, minidx2, minidx3, sep='\n')
# Out:
# [[ 0  1 10]
#  [20  8  5]]
# 0
# [0 0 1]
# [0 2]

# %% [markdown]
# # Mean and Variance

# %%
x = [1, 2, 4, 6, 5, 4, 0]
n = len(x)

# %%
# using numpy's mean function
mean1 = np.mean(x)
# using custom computation
mean2 = np.sum(x)/n
print(mean1)
print(mean2)
# Out:
# 3.142857142857143
# 3.142857142857143

# %%
# variance
# using numpy's var function
var1 = np.var(x) # here calculates the population variance not sample variance

# using cutom compuation
var2 = (1/(n-1)) * np.sum((x-mean1)**2)

# using numpy's var function with 1 degrees of freedom
var3 = np.var(x, ddof=1)
print(var1)
print(var2)
print(var3)
# Out:
# 4.122448979591836
# 4.809523809523809
# 4.809523809523809

# %% [markdown]
# # Random Sampling and Sampling Variability

# %%
x = [1, 2, 3, 4, 6, 5, 4, 0, -4, 5, -2, 6, 10, -9, 1, 3, -6]
n = len(x)

popmean = np.mean(x)
sample = np.random.choice(x, size=5, replace=True)
sampmean = np.mean(sample)

print(popmean)
print(sampmean)
# Out:
# 1.7058823529411764
# 4.0

# %%
# compute lots of sample means

# number of experiments to run

nExpers = 10000

sampleMeans = np.zeros(nExpers)

for i in range(nExpers):
  sample = np.random.choice(x, size=5, replace=True)
  sampleMeans[i] = np.mean(sample)

plt.hist(sampleMeans, bins=40, density=True)
plt.plot([popmean, popmean], [0, .3], 'm--')
plt.xlabel('Sample Mean')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Reproducible randomness via seeding

# %%
import numpy as np
import torch

# %%
np.random.seed(12)
#[ 0.47 -0.68  0.24 -1.7   0.75]
#[-1.53  0.01 -0.12 -0.81  2.87]

print(np.random.randn(5))
print(np.random.randn(5))
# Out:
# [ 0.47298583 -0.68142588  0.2424395  -1.70073563  0.75314283]
# [-1.53472134  0.00512708 -0.12022767 -0.80698188  2.87181939]

# %% [markdown]
# ## New seed mechanism in numpy

# %%
randseed1 = np.random.RandomState(18)
randseed2 = np.random.RandomState(2002)

#[ 0.08  2.19 -0.13  0.16  0.44]
#[-1.31  1.    1.76  2.91 -0.69]
#[ 0.62  1.01  0.39 -0.34 -0.65]
#[ 0.3  -1.19 -0.4   1.81 -0.12]
#[-0.6   0.47  1.1  -1.22  1.34]


print(randseed1.randn(5))
print(randseed2.randn(5))
print(randseed1.randn(5))
print(randseed2.randn(5))
print(np.random.randn(5))
# Out:
# [ 0.07942844  2.19020236 -0.13489215  0.16051798  0.44269784]
# [-1.30564946  0.9951862   1.7568906   2.90793288 -0.68513539]
# [ 0.62339144  1.00890349  0.39424879 -0.3363867  -0.64590646]
# [ 0.29954648 -1.18822358 -0.39922581  1.81410631 -0.12403362]
# [-0.59782292  0.47245699  1.09595612 -1.2151688   1.34235637]

# %% [markdown]
# ## Using Pytorch

# %%
torch.randn(5)
# Out:
# tensor([-0.88,  0.87, -0.69,  0.26, -0.44])

# %%
torch.manual_seed(18)
print(torch.randn(5))
print(np.random.randn(5))
# Out:
# tensor([ 0.59, -0.13, -0.73,  0.72, -0.57])
# [-0.12214979  1.01251548 -0.91386915 -1.02953021  1.20979645]

# %% [markdown]
# # Derivatives

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym
import sympy.plotting.plot as symplot

# %%
x = sym.symbols('x')
fx = 2*x**2
df = sym.diff(fx, x)

# %%
fx
# Out:
# 2*x**2

# %%
df
# Out:
# 4*x

# %%
symplot(fx, (x, -4, 4), title='The function')
plt.show()

# %%
symplot(df, (x, -4, 4), title='Its derivative')
plt.show()

# %%
# relu and sigmoid

relu = sym.Max(0, x)
sigmoid = 1/(1+sym.exp(-x))

p = symplot(relu, (x, -10, 10), label='ReLU', show=False, line_color='blue')
p.extend(symplot(sigmoid, (x, -10, 10), label='Sigmoid', show=False, line_color='red'))
p.legend = True
p.title = 'The functions'
p.show()

# %% [markdown]
# # Gradient Descent

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display

display.set_matplotlib_formats('svg')

# %% [markdown]
# ## Gradient descent for 1D

# %%
# define a function

def fx(x):
  return 3*x**2 - 3*x + 4


# derivative function

def deriv(x):
  return 6*x - 3

# %%
# plot of the function and its derivative

x = np.linspace(-2, 2, 2001)

plt.plot(x, fx(x),x,  deriv(x))
plt.xlim(x[[0, -1]])
plt.grid()
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(['y', 'dy'])
plt.show()

# %%
# random starting point for gradient descent

localmin = np.random.choice(x, 1)

# learning parameters
learning_rate = .01
training_epochs = 100

for i in range(training_epochs):
  grad = deriv(localmin)
  localmin = localmin - learning_rate*grad
localmin
# Out:
# array([0.5027412])

# %% [markdown]
# ## Code challenge

# %%
# f(x) = cos(2pix) + x^2 x in [-2, 2]
def fx(x):
  return np.cos(2*np.pi*x) + x**2

def deriv(x):
  return -2*np.pi*np.sin(2*np.pi*x) + 2*x

# %%
x = np.linspace(-2, 2, 30001)
plt.plot(x, fx(x), x, deriv(x))
plt.xlim(x[[0, -1]])
plt.grid()
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(['y', 'dy'])
plt.show()

# %%
localmin = np.random.choice(x, 1)
print(f'First guess for local minimum is {localmin}.')
learning_rate = 0.1
training_epochs = 100

for i in range(training_epochs):
  grad = deriv(localmin)
  localmin = localmin - learning_rate*grad

print(f'Estimated local minimum is {localmin}')
# Out:
# First guess for local minimum is [-0.15573333].
# Estimated local minimum is [0.14365937]

# %% [markdown]
# # Gradient Descent in 2D

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym

from IPython import display
display.set_matplotlib_formats('svg')

# %% [markdown]
# ## Implementation of 2D gradient descent

# %%
def peaks(x, y):
  x, y = np.meshgrid(x, y)
  z = 3*(1-x)**2*np.exp(-(x**2) - (y+1)**2) \
  -10*(x/5-x**3-y**5) * np.exp(-x**2-y**2) \
  -1/3*np.exp(-(x+1)**2-y**2)
  return z

# %%
x = np.linspace(-3, 3, 201)
y = np.linspace(-3, 3, 201)

Z = peaks(x, y)

plt.imshow(Z, extent=[x[0], x[-1], y[0], y[-1]], vmin=-5, vmax=5, origin='lower')
plt.show()

# %%
sx, sy = sym.symbols('sx,sy')
sZ = 3*(1-sx)**2*sym.exp(-(sx**2)-(sy+1)**2) \
      -10*(sx/5-sx**3-sy**5)*sym.exp(-sx**2-sy**2) \
      - 1/3*sym.exp(-(sx+1)**2-sy**2)


dfx = sym.lambdify((sx, sy), sym.diff(sZ, sx), 'sympy')
dfy = sym.lambdify((sx, sy), sym.diff(sZ, sy), 'sympy')

dfx(1,1).evalf()
# Out:
# -1.07369833656079

# %%
# random starting point
localmin = np.random.rand(2)*4-2
startpnt = localmin[:]

# learning parameters
learning_rate = .01
training_epochs = 1000

# run through training
trajectory = np.zeros((training_epochs, 2))
for i in range(training_epochs):
  grad = np.array([dfx(localmin[0], localmin[1]).evalf(),
                   dfy(localmin[0], localmin[1]).evalf()])
  localmin = localmin - learning_rate*grad
  trajectory[i, :] = localmin

print(localmin)
print(startpnt)
# Out:
# [0.228278920556369 -1.62553495750000]
# [-0.32401798 -0.94598481]

# %%
plt.imshow(Z, extent=[x[0], x[-1], y[0], y[-1]], vmin=-5, vmax=5, origin='lower')
plt.plot(startpnt[0], startpnt[1], 'bs')
plt.plot(localmin[0], localmin[1], 'ro')
plt.plot(trajectory[:, 0], trajectory[:, 1], 'r')
plt.legend(['rnd start', 'local min'])
plt.colorbar()
plt.show()

# %% [markdown]
# ## Running experiments to understand gradient descent

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 401)
fx = np.sin(x)*np.exp(-x**2*.05)
zeros = np.zeros(len(x))
df = np.cos(x)*np.exp(-x**2*.05) + np.sin(x)*(-.1*x)*np.exp(-x**2*.05)
plt.plot(x, fx, x, df, x, zeros)
plt.legend(['fx', 'df', 'y=0'])
plt.show();

# %%
def fx(x):
  return np.sin(x) * np.exp(-x**2*.05)

def deriv(x):
  return np.cos(x)*np.exp(-x**2*.05) - np.sin(x)*.1*x*np.exp(-x**2*.05)

# %%
localmin = np.random.choice(x, 1)

# learning parameters

learning_rate = .01
learning_epochs = 1000

# run through training
for i in range(training_epochs):
  grad = deriv(localmin)
  localmin = localmin - learning_rate*grad

plt.plot(x, fx(x), x, deriv(x), '--')
plt.plot(localmin, deriv(localmin), 'ro')
plt.plot(localmin, fx(localmin), 'ro')

plt.xlim(x[[0, -1]])
plt.grid()
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(['f(x)', 'df', 'f(x) min'])
plt.title('Empirical local minimum: %s'%localmin[0])
plt.show()

# %% [markdown]
# ## Run parametric experiments

# %%
# Experiment 1: systematically varying the starting locations

startlocs = np.linspace(-5, 5, 50)
finalres = np.zeros(len(startlocs))

for idx, localmin in enumerate(startlocs):
  for i in range(training_epochs):
    grad = deriv(localmin)
    localmin = localmin - learning_rate*grad
  finalres[idx] = localmin

plt.plot(startlocs, finalres, 's-')
plt.xlabel('Starting guess')
plt.ylabel('Final guess')
plt.show()

# %% [markdown]
# ## Systematically varying the learning rates

# %%
learningrates = np.linspace(1e-10, 1e-1, 50)
finalres = np.zeros(len(learningrates))
for idx, learningRate in enumerate(learningrates):
  localmin = 0
  for i in range(training_epochs):
    grad = deriv(localmin)
    localmin = localmin - learningRate*grad
  finalres[idx] = localmin

plt.plot(learningrates, finalres, 's-')
plt.xlabel('Learning Rate')
plt.ylabel('Final Guess')
plt.show()

# %% [markdown]
# ## Interaction b-ween learning rate and training epochs

# %%
learningrates = np.linspace(1e-10, 1e-1, 50)
training_epochs = np.round(np.linspace(10, 500, 40))
finalres = np.zeros((len(learningrates), len(training_epochs)))
for Lidx, learningRate in enumerate(learningrates):
  for Eidx, trainEpochs in enumerate(training_epochs):
    localmin = 0
    for i in range(int(trainEpochs)):
      grad = deriv(localmin)
      localmin = localmin - grad*learningRate
    finalres[Lidx, Eidx] = localmin

# %%
fig, ax = plt.subplots(figsize=(7, 5))
plt.imshow(finalres, extent=[learningrates[0], learningrates[-1], training_epochs[0], training_epochs[-1]],
           aspect='auto', origin='bottom', vmin=-1.45, vmax=-1.2)
plt.xlabel('Learning Rate')
plt.ylabel('Training Epochs')
plt.title('Final Guess')
plt.colorbar()
plt.show()

plt.plot(learningrates, finalres)
plt.xlabel('Learning rates')
plt.ylabel('Final function estimate')
plt.title('Each line is a training epochs N')
plt.show()

# %% [markdown]
# # CodeChallenge: Fixed vs. Dynamic Learning Rate

# %%
import numpy as np
import matplotlib.pyplot as plt

from IPython import display
display.set_matplotlib_formats('svg')

# %%
x = np.linspace(-2, 2, 2001)

def fx(x):
  return 3*x**2 - 3*x + 4

def deriv(x):
  return 6*x - 3

# %% [markdown]
# ## Gradient Descent using fixed learning rate

# %%
localmin = np.random.choice(x, 1)
initval = localmin[:]

learning_rate = .01
training_epochs = 50

modelparamsFixed = np.zeros((training_epochs, 3))
for i in range(training_epochs):
  grad = deriv(localmin)
  lr = learning_rate
  localmin = localmin - grad*lr
  modelparamsFixed[i, :] = localmin, grad, lr
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   if sys.path[0] == '':

# %% [markdown]
# ## Gradient Descent using gradient-based learning rate

# %%
localmin = np.random.choice(x, 1)
initval = localmin[:]
learning_rate = .01
training_epochs = 50
modelparamsGrad = np.zeros((training_epochs, 3))
for i in range(training_epochs):
  grad = deriv(localmin)
  lr = learning_rate*np.abs(grad)
  localmin = localmin - lr*grad
  modelparamsGrad[i, :] = localmin, grad, lr
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   # Remove the CWD from sys.path while we load stuff.
